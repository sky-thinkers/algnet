# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('../build/metrics/summary.csv', delimiter=',', skiprows=1, usecols=2)

# %%
fig, ax = plt.subplots(dpi=100)
ax.ecdf(data)
ax.set_xlabel('Throughput (Gbps)')
ax.set_ylabel('CDF')
# Out:
# Text(0, 0.5, 'CDF')
